# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name               str
# Product_ID              str
# Gender                  str
# Age Group               str
# Age                   int64
# Marital_Status        int64
# State                   str
# Zone                    str
# Occupation              str
# Product_Category        str
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.tail(10)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11241  1003032     Matthias  P00058042      F     26-35   33               0
# 11242  1004344   Hildebrand  P00185442      F     26-35   27               1
# 11243  1005446      Sheetal  P00297742      M     51-55   53               0
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11245  1004140    Bertelson  P00057442      F     26-35   31               1
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
df.isnull().sum() # finding and summing the null values count
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df["Filled_Amount"] = df["Amount"].fillna(df["Amount"].mean())

# %%
df[df.duplicated()] # display the duplicated rows
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 19     1001883     Praneet  P00029842      M     51-55   54               1
# 4404   1004725     Jackson  P00150842      F     36-45   37               1
# 5703   1003208      Bowman  P00171642      F     26-35   31               0
# 5908   1001260     Dheeraj  P00344042      M     26-35   28               0
# 6173   1001325       Reese  P00111742      F     26-35   27               1
# 8651   1000083        Gute  P00242842      M     26-35   35               0
# 8941   1001476     Anudeep  P00036842      M     18-25   25               0
# 10571  1004404  Rittenbach  P00150142      F     26-35   28               1
#
#                State      Zone    Occupation       Product_Category  Orders  \
# 19     Uttar Pradesh   Central   Hospitality                   Auto       1
# 4404     Maharashtra   Western   Hospitality  Electronics & Gadgets       4
# ...

# %%
df = df.drop_duplicates() # removing the duplicated rows from the datasets.

# %%
df.duplicated().sum() # cross-checking the dataset. Is any duplicated rows left.
# Out:
# np.int64(0)

# %%
df.drop("Status", axis = 1, inplace= True) # Removing the Status columns because It is empty or containing NA.

# %%
df.drop("unnamed1", axis = 1, inplace= True) # Removing the unnamed1 columns

# %%
df.describe() # Question: Generate a statistical summary of all numerical columns in the cleaned dataset.
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.124300e+04  11243.000000    11243.000000  11243.000000  11231.000000
# mean   1.003005e+06     35.422841        0.420261      2.488749   9454.084982
# std    1.716141e+03     12.756369        0.493623      1.114960   5221.728776
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001494e+06     27.000000        0.000000      1.000000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12677.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Filled_Amount
# count   11243.000000
# mean     9454.084476
# std      5218.941128
# min       188.000000
# 25%      5444.000000
# 50%      8111.000000
# 75%     12672.000000
# max     23952.000000

# %%
gender_count = df.groupby("Gender")["User_ID"].count() # number of records for each gender.

print(gender_count)
# Out:
# Gender
# F    7838
# M    3405
# Name: User_ID, dtype: int64

# %% [markdown]
# ### Female customers represent approximately 69.7% of the records, while male customers represent approximately 30.3%. Therefore, female customers account for more than twice the number of male customers in the dataset.

# %%
gender_percentage = (gender_count / len(df)) * 100

print(gender_percentage)
# Out:
# Gender
# F    69.714489
# M    30.285511
# Name: User_ID, dtype: float64

# %% [markdown]
# ## 📊 What does this tell us?
# ### Female customers contribute much higher total revenue — about ₹7.43 crore versus ₹3.19 crore for male customers.
# ### Female customers also have a slightly higher average spending per record: ₹9,492.55 vs ₹9,365.60.
# ### So in this dataset, female customers lead both in customer count and total revenue, and their average transaction value is also marginally higher.

# %%
gender_revenue = df.groupby("Gender")["Amount"].sum() # total amount spent by Male and female.
print(gender_revenue)

gender_revenue_avg = df.groupby("Gender")["Amount"].mean() # Average amount spent by Male and female
print(gender_revenue_avg)
# Out:
# Gender
# F    74307682.43
# M    31871146.00
# Name: Amount, dtype: float64
# Gender
# F    9492.550132
# M    9365.602703
# Name: Amount, dtype: float64

# %%
age_group = df.groupby("Age Group")["User_ID"].count() # counting the people between different Age group.
print(age_group)

age_group_percentage = (age_group / len(df)) * 100 # calculating the percentage of the different Age Group.
print(age_group_percentage)
# Out:
# Age Group
# 0-17      296
# 18-25    1878
# 26-35    4538
# 36-45    2285
# 46-50     987
# 51-55     831
# 55+       428
# Name: User_ID, dtype: int64
# Age Group
# 0-17      2.632749
# 18-25    16.703727
# 26-35    40.362892
# 36-45    20.323757
# 46-50     8.778796
# 51-55     7.391266
# 55+       3.806813
# Name: User_ID, dtype: float64

# %% [markdown]
# ###  26–35 is clearly the dominant age group, representing about 40.36% of the records. The next largest group is 36–45 at 20.32%.
#
# ### So roughly 60.7% of the records come from customers aged 26–45.

# %%
revenue_age_group_sum = df.groupby("Age Group")["Amount"].sum() # calculating the revenue based on the Age groups
print(revenue_age_group_sum)

revenue_age_group_avg = df.groupby("Age Group")["Amount"].mean()
print(revenue_age_group_avg)
# Out:
# Age Group
# 0-17      2699653.00
# 18-25    17235530.00
# 26-35    42581768.94
# 36-45    22135136.49
# 46-50     9207844.00
# 51-55     8237909.00
# 55+       4080987.00
# Name: Amount, dtype: float64
# Age Group
# 0-17     9120.449324
# 18-25    9177.598509
# 26-35    9387.515198
# 36-45    9699.884527
# 46-50    9367.084435
# 51-55    9937.164053
# 55+      9557.346604
# Name: Amount, dtype: float64

# %% [markdown]
# ### 26–35 is the largest customer segment and generates the highest total revenue, while 51–55 has the highest average spending per transaction.

# %%
gender_age_group_revenue = df.groupby(["Gender","Age Group"])["Amount"].sum()
print(gender_age_group_revenue)

gender_age_group_revenue_avg = df.groupby(["Gender","Age Group"])["Amount"].mean()
print(gender_age_group_revenue_avg)
# Out:
# Gender  Age Group
# F       0-17          1441409.00
#         18-25        11887003.00
#         26-35        30945639.94
#         36-45        15500098.49
#         46-50         6743393.00
#         51-55         5385208.00
#         55+           2404931.00
# M       0-17          1258244.00
#         18-25         5348527.00
#         26-35        11636129.00
#         36-45         6635038.00
#         46-50         2464451.00
#         51-55         2852701.00
#         55+           1676056.00
# Name: Amount, dtype: float64
# Gender  Age Group
# F       0-17          8897.586420
#         18-25         9108.814559
#         26-35         9475.088775
#         36-45         9828.851294
#         46-50         9730.725830
#         51-55         9738.169982
#         55+           8841.658088
# M       0-17          9389.880597
#         18-25         9334.253054
#         26-35         9162.306299
#         36-45         9411.401418
#         46-50         8498.106897
# ...

# %% [markdown]
# ## Female 26–35 is the biggest revenue-generating segment because of its large customer base, while Male 55+ has the highest average spending per transaction.

# %%
product_revenue = df.groupby("Product_Category")["Amount"].sum()
print(product_revenue)

product_revenue_avg = df.groupby("Product_Category")["Amount"].mean()
print(product_revenue_avg)

sort = product_revenue.sort_values(ascending= False)
print(sort.head(10))
# Out:
# Product_Category
# Auto                      1935041.99
# Beauty                    1959484.00
# Books                     1061478.00
# Clothing & Apparel       16484472.00
# Decor                      730360.00
# Electronics & Gadgets    15607657.00
# Food                     33933883.50
# Footwear & Shoes         15575209.45
# Furniture                 5440051.99
# Games & Toys              4331694.00
# Hand & Power Tools         405618.00
# Household items           1569337.00
# Office                      81936.00
# Pet Care                   482277.00
# Sports Products           3635933.00
# Stationery                1676051.50
# Tupperware                1155642.00
# Veterinary                 112702.00
# Name: Amount, dtype: float64
# Product_Category
# Auto                     20156.687396
# Beauty                    4643.327014
# Books                    10305.611650
# Clothing & Apparel        6213.521297
# Decor                     7607.916667
# ...

# %% [markdown]
# ### Food is the clear revenue leader, generating about ₹3.39 crore, roughly twice the revenue of the second-highest category, Clothing & Apparel.

# %%
total_orders_category = df.groupby("Product_Category")["Orders"].sum()
#print(total_orders_category)

category_order_vs_revenue = df.groupby("Product_Category").agg(
    Total_Orders=("Orders", "sum"),
    Total_Revenue=("Filled_Amount", "sum")
)

#print(category_order_vs_revenue)

category_order_vs_revenue = category_order_vs_revenue.sort_values(
    "Total_Orders",
    ascending=False
)

print(category_order_vs_revenue)
# Out:
#                        Total_Orders  Total_Revenue
# Product_Category
# Clothing & Apparel             6627   1.648447e+07
# Food                           6120   3.396224e+07
# Electronics & Gadgets          5208   1.560766e+07
# Footwear & Shoes               2654   1.562248e+07
# Household items                1331   1.569337e+06
# Beauty                         1086   1.959484e+06
# Games & Toys                    940   4.331694e+06
# Furniture                       890   5.449506e+06
# Sports Products                 870   3.635933e+06
# Pet Care                        536   4.822770e+05
# Stationery                      281   1.676052e+06
# Office                          261   8.193600e+04
# Auto                            245   1.963403e+06
# Books                           245   1.061478e+06
# Decor                           235   7.303600e+05
# Veterinary                      206   1.127020e+05
# Tupperware                      166   1.155642e+06
# ...

# %% [markdown]
# ## 🏆 Highest order category
#
# ### Clothing & Apparel — 6,627 orders
#
# ## 🔻 Lowest order category
#
# ### Hand & Power Tools — 80 orders
#
# ### 💰 But here's the interesting part
#
# ### The category with the most orders is NOT the highest-revenue category.
#
# ## Clothing & Apparel → 6,627 orders, ₹16.48M revenue
# ### Food → 6,120 orders, ₹33.96M revenue 🥇
#
# ### Clothing & Apparel has the highest order volume, while Food generates the highest revenue, indicating substantially higher revenue per order in the Food category.

# %%
product_revenue = df.groupby("Product_Category")["Filled_Amount"].sum()
total_orders_category = df.groupby("Product_Category")["Orders"].sum()

avg_revenue = product_revenue/total_orders_category
#print(avg_revenue)
print(avg_revenue.sort_values(ascending=False))
# Out:
# Product_Category
# Auto                     8013.889072
# Tupperware               6961.698795
# Furniture                6123.040001
# Stationery               5964.596085
# Footwear & Shoes         5886.389414
# Food                     5549.386329
# Hand & Power Tools       5070.225000
# Games & Toys             4608.185106
# Books                    4332.563265
# Sports Products          4179.233333
# Decor                    3107.914894
# Electronics & Gadgets    2996.861943
# Clothing & Apparel       2487.471254
# Beauty                   1804.313076
# Household items          1179.066116
# Pet Care                  899.770522
# Veterinary                547.097087
# Office                    313.931034
# dtype: float64

# %% [markdown]
# ## 🥇 Highest: Auto → ₹8,013.89 per order
# ## 🥈 Tupperware → ₹6,961.70
# ## Furniture → ₹6,123.04
# ### ...
# ## 🥉 Lowest: Office → ₹313.93 per order
# ## 💡 Business insight
#
# ## This is actually a good resume-level insight:
#
# ### Auto generates the highest average revenue per order (₹8,013.89), while Office generates the lowest (₹313.93). This shows that order volume and revenue per order can tell very different stories—high-order categories aren't necessarily the most valuable on a per-order basis.
#
# ## And notice something interesting 👀:
#
# ### Clothing & Apparel had the highest number of orders, but its average revenue per order is only ₹2,487.47.

# %%
category_gender_revenue = df.groupby(["Product_Category","Gender"])["Filled_Amount"].sum().reset_index()
print(category_gender_revenue)
# Out:
#          Product_Category Gender  Filled_Amount
# 0                    Auto      F   1.304699e+06
# 1                    Auto      M   6.587036e+05
# 2                  Beauty      F   1.524257e+06
# 3                  Beauty      M   4.352270e+05
# 4                   Books      F   4.042150e+05
# 5                   Books      M   6.572630e+05
# 6      Clothing & Apparel      F   1.147910e+07
# 7      Clothing & Apparel      M   5.005369e+06
# 8                   Decor      F   5.969940e+05
# 9                   Decor      M   1.333660e+05
# 10  Electronics & Gadgets      F   1.100492e+07
# 11  Electronics & Gadgets      M   4.602734e+06
# 12                   Food      F   2.420446e+07
# 13                   Food      M   9.757781e+06
# 14       Footwear & Shoes      F   1.157236e+07
# 15       Footwear & Shoes      M   4.050116e+06
# 16              Furniture      F   3.404097e+06
# 17              Furniture      M   2.045409e+06
# 18           Games & Toys      F   3.045258e+06
# ...

# %%
states_revenue = df.groupby("State")["Filled_Amount"].sum()
print(states_revenue) 

states_orders = df.groupby("State")["Orders"].sum()
print(states_orders)
# Out:
# State
# Andhra Pradesh      8.046601e+06
# Bihar               4.014669e+06
# Delhi               1.163218e+07
# Gujarat             3.957066e+06
# Haryana             4.217871e+06
# Himachal Pradesh    4.963368e+06
# Jharkhand           3.026456e+06
# Karnataka           1.353299e+07
# Kerala              3.894492e+06
# Madhya Pradesh      8.120049e+06
# Maharashtra         1.441392e+07
# Punjab              1.525800e+06
# Rajasthan           1.909409e+06
# Telangana           1.151490e+06
# Uttar Pradesh       1.936496e+07
# Uttarakhand         2.520944e+06
# Name: Filled_Amount, dtype: float64
# State
# Andhra Pradesh      2054
# Bihar               1058
# Delhi               2744
# Gujarat             1067
# Haryana             1106
# Himachal Pradesh    1568
# Jharkhand            953
# Karnataka           3241
# Kerala              1137
# Madhya Pradesh      2259
# Maharashtra         3799
# Punjab               495
# Rajasthan            555
# Telangana            312
# ...

# %% [markdown]
# ## 💰 Revenue ranking
#
# ## Your top 3 states by revenue are:
#
#     Uttar Pradesh → ₹19.36M
#     Maharashtra → ₹14.41M
#     Karnataka → ₹13.53M
#
# ## 📦 Order ranking
#
# ## Top 3 by total orders:
#
#     Uttar Pradesh → 4,809
#     Maharashtra → 3,799
#     Karnataka → 3,241
#
# ## And there's a nice observation here:
#
# ### Uttar Pradesh leads both total orders and total revenue, while Telangana has the lowest orders and revenue among the listed states.

# %%
avg_revenue_per_Order_by_states = states_revenue/states_orders
print(avg_revenue_per_Order_by_states.sort_values(ascending=False))
# Out:
# State
# Delhi               4239.132756
# Karnataka           4175.561126
# Uttar Pradesh       4026.816848
# Andhra Pradesh      3917.527070
# Haryana             3813.626582
# Bihar               3794.583176
# Maharashtra         3794.135460
# Gujarat             3708.590648
# Telangana           3690.673077
# Madhya Pradesh      3594.532635
# Rajasthan           3440.376577
# Kerala              3425.234820
# Jharkhand           3175.714586
# Himachal Pradesh    3165.413265
# Punjab              3082.424242
# Uttarakhand         3059.398058
# dtype: float64

# %% [markdown]
#     🥇 Delhi: ₹4,239.13 per order
#     🥈 Karnataka: ₹4,175.56
#     🥉 Uttar Pradesh: ₹4,026.82
#     ...
#     🔻 Uttarakhand: ₹3,059.40 per order
#
# ## Look at Uttar Pradesh:
#
#     Highest total revenue → ₹19.36M
#     Highest total orders → 4,809
#     But average revenue/order → ₹4,026.82
#
# ### Delhi has a higher revenue per order (₹4,239.13) despite having considerably fewer total orders.
#
# ### So: High total revenue doesn't necessarily mean the state has the highest-value orders.

# %%
states_gender_revenue = df.groupby(["State","Gender"])["Filled_Amount"].sum()
print(states_gender_revenue)
# Out:
# State             Gender
# Andhra Pradesh    F         5.520674e+06
#                   M         2.525927e+06
# Bihar             F         2.811193e+06
#                   M         1.203476e+06
# Delhi             F         8.292860e+06
#                   M         3.339320e+06
# Gujarat           F         2.833793e+06
#                   M         1.123274e+06
# Haryana           F         3.195992e+06
#                   M         1.021879e+06
# Himachal Pradesh  F         3.163299e+06
#                   M         1.800069e+06
# Jharkhand         F         1.954275e+06
#                   M         1.072181e+06
# Karnataka         F         9.943420e+06
#                   M         3.589574e+06
# Kerala            F         2.644088e+06
#                   M         1.250404e+06
# Madhya Pradesh    F         5.310500e+06
#                   M         2.809550e+06
# Maharashtra       F         1.056057e+07
#                   M         3.853350e+06
# ...

# %% [markdown]
#     Female revenue is higher than male revenue across all 16 states.
#     Uttar Pradesh has the highest female revenue (~₹13.68M).
#     Maharashtra is next (~₹10.56M), followed by Karnataka (~₹9.94M).
#     The gender gap is especially large in major revenue-generating states.
#
#
# ### “Female customers contribute significantly more revenue than male customers across all states, indicating that women are the dominant revenue-generating customer segment in the dataset.”

# %%
revenue_occupation = df.groupby("Occupation")["Filled_Amount"].sum()
#print(revenue_occupation.sort_values(ascending=False))
top_5= revenue_occupation.sort_values(ascending=False).head(5)
bottom_5 = revenue_occupation.sort_values(ascending=False).tail(5)
print(top_5)
print(bottom_5)
# Out:
# Occupation
# IT Sector     1.478913e+07
# Healthcare    1.303459e+07
# Aviation      1.259999e+07
# Banking       1.078952e+07
# Govt          8.517212e+06
# Name: Filled_Amount, dtype: float64
# Occupation
# Retail             4.783170e+06
# Food Processing    4.070670e+06
# Construction       3.589588e+06
# Textile            3.214426e+06
# Agriculture        2.584999e+06
# Name: Filled_Amount, dtype: float64

# %% [markdown]
# ## Top 5:
#
#     IT Sector — ₹14.79M
#     Healthcare — ₹13.03M
#     Aviation — ₹12.60M
#     Banking — ₹10.79M
#     Govt — ₹8.52M
#
# ## Bottom 5:
#
#     Agriculture — ₹2.58M
#     Textile — ₹3.21M
#     Construction — ₹3.59M
#     Food Processing — ₹4.07M
#     Retail — ₹4.78M
# ## 💡 Business insight
#
# ### IT Sector generates the highest revenue, followed by Healthcare and Aviation, while Agriculture generates the lowest revenue among the occupations.

# %%
order_occupation = df.groupby("Occupation")["Orders"].sum()
print(revenue_occupation.sort_values(ascending=False), order_occupation.sort_values(ascending=False))
# Out:
# Occupation
# IT Sector          1.478913e+07
# Healthcare         1.303459e+07
# Aviation           1.259999e+07
# Banking            1.078952e+07
# Govt               8.517212e+06
# Hospitality        6.356540e+06
# Media              6.295833e+06
# Automobile         5.378050e+06
# Chemical           5.306890e+06
# Lawyer             4.981665e+06
# Retail             4.783170e+06
# Food Processing    4.070670e+06
# Construction       3.589588e+06
# Textile            3.214426e+06
# Agriculture        2.584999e+06
# Name: Filled_Amount, dtype: float64 Occupation
# IT Sector          4002
# Healthcare         3455
# Aviation           3212
# Banking            2819
# Govt               2155
# Hospitality        1738
# Media              1596
# Automobile         1373
# Lawyer             1344
# Chemical           1310
# Retail             1270
# Food Processing    1073
# Construction       1022
# Textile             894
# Agriculture         718
# Name: Orders, dtype: int64

# %% [markdown]
# ## 💡 Insight
# ### The ranking is almost perfectly aligned:
#
#     IT Sector → highest revenue and highest orders
#     Healthcare → 2nd in both
#     Aviation → 3rd in both
#     Banking → 4th in both
#     Govt → 5th in both
#
# ### So here, higher order volume is strongly associated with higher total revenue.

# %%
avg_revenue_per_Order_by_Occupation = revenue_occupation/order_occupation
print(avg_revenue_per_Order_by_Occupation.sort_values(ascending=False))
# Out:
# Occupation
# Chemical           4051.060772
# Govt               3952.302552
# Media              3944.757513
# Aviation           3922.787671
# Automobile         3917.006272
# Banking            3827.427517
# Food Processing    3793.727866
# Healthcare         3772.673658
# Retail             3766.275591
# Lawyer             3706.595982
# IT Sector          3695.434796
# Hospitality        3657.387930
# Agriculture        3600.277159
# Textile            3595.554375
# Construction       3512.317025
# dtype: float64

# %% [markdown]
# ## 🏆 Top 5
#
#     Chemical — ₹4,051.06/order
#     Govt — ₹3,952.30/order
#     Media — ₹3,944.76/order
#     Aviation — ₹3,922.79/order
#     Automobile — ₹3,917.01/order
# ## 🔻 Lowest 5
#
#     Construction — ₹3,512.32
#     Textile — ₹3,595.55
#     Agriculture — ₹3,600.28
#     Hospitality — ₹3,657.39
#     IT Sector — ₹3,695.43
#
#
# ### IT Sector has the highest total revenue and highest order volume, but it does NOT have the highest revenue per order.
#
# #### Chemical has the highest average revenue/order, despite being much lower in total revenue.
#
# ### So: High total revenue is mainly driven by order volume, while high revenue per order depends on the value generated from each order.

# %%
revenue_by_Gender_and_Occupation = df.groupby(["Occupation","Gender"])["Filled_Amount"].sum()
print(revenue_by_Gender_and_Occupation.sort_values(ascending=False))
# Out:
# Occupation       Gender
# IT Sector        F         1.022265e+07
# Aviation         F         9.005089e+06
# Healthcare       F         8.968232e+06
# Banking          F         7.811203e+06
# Govt             F         6.002907e+06
# IT Sector        M         4.566481e+06
# Media            F         4.375030e+06
# Hospitality      F         4.182794e+06
# Healthcare       M         4.066355e+06
# Automobile       F         3.778297e+06
# Chemical         F         3.674538e+06
# Aviation         M         3.594905e+06
# Retail           F         3.583695e+06
# Lawyer           F         3.383409e+06
# Banking          M         2.978315e+06
# Food Processing  F         2.825277e+06
# Construction     F         2.587499e+06
# Govt             M         2.514305e+06
# Hospitality      M         2.173747e+06
# Textile          F         2.169206e+06
# Media            M         1.920803e+06
# Agriculture      F         1.832394e+06
# Chemical         M         1.632352e+06
# ...

# %% [markdown]
# Female customers generate more revenue than male customers in every occupation.
#
# For example:
#
#     IT Sector → F ₹10.22M vs M ₹4.57M
#     Aviation → F ₹9.01M vs M ₹3.59M
#     Healthcare → F ₹8.97M vs M ₹4.07M
#     Banking → F ₹7.81M vs M ₹2.98M
#     Govt → F ₹6.00M vs M ₹2.51M
#
# So the pattern from Q19 (State × Gender) appears again at the occupation level:
#
# Female customers are the dominant revenue contributors across all occupations in this dataset.

# %%
revenue_by_Gender_and_Occupation = df.groupby(["Occupation","Gender"])["Filled_Amount"].sum()
order_by_Gender_and_Occupation = df.groupby(["Occupation","Gender"])["Orders"].sum()
avg_revenue_by_gender_by_Occupation = revenue_by_Gender_and_Occupation/order_by_Gender_and_Occupation
print(avg_revenue_by_gender_by_Occupation)
# Out:
# Occupation       Gender
# Agriculture      F         3544.282398
#                  M         3744.303483
# Automobile       F         3964.634429
#                  M         3808.935714
# Aviation         F         3916.959113
#                  M         3937.464403
# Banking          F         3840.316210
#                  M         3794.031847
# Chemical         F         3976.772306
#                  M         4228.891192
# Construction     F         3554.256868
#                  M         3408.465986
# Food Processing  F         3772.065421
#                  M         3843.805556
# Govt             F         3983.349038
#                  M         3880.100309
# Healthcare       F         3732.098414
#                  M         3865.356464
# Hospitality      F         3547.746913
#                  M         3888.634366
# IT Sector        F         3784.764696
#                  M         3509.977410
# Lawyer           F         3645.914871
# ...

# %% [markdown]
# ## 🏆 Top 5 occupation × gender combinations
#     Chemical – Male: ₹4,228.89/order
#     Media – Female: ₹4,092.64/order
#     Automobile – Female: ₹3,964.63/order
#     Govt – Female: ₹3,983.35/order
#     Aviation – Male: ₹3,937.46/order
#
# ## 🔻 Lowest 5
#     Construction – Male: ₹3,408.47
#     IT Sector – Male: ₹3,509.98
#     Agriculture – Female: ₹3,544.28
#     Hospitality – Female: ₹3,547.75
#     Construction – Female: ₹3,554.26
# ##🔥 Most interesting finding
#
# ### This is a really good insight:
#     Although female customers generate higher total revenue across every occupation, males have a higher average revenue per order in several occupations.

# %%
total_revenue_by_agegroup = df.groupby(["Age Group","Product_Category"])["Filled_Amount"].sum()
#print(total_revenue_by_agegroup)


highest_revenue_category = total_revenue_by_agegroup.groupby(
    level="Age Group"
).idxmax()

print(total_revenue_by_agegroup.loc[highest_revenue_category])
# Out:
# Age Group  Product_Category
# 0-17       Food                1.079989e+06
# 18-25      Food                6.578809e+06
# 26-35      Food                1.364028e+07
# 36-45      Food                6.256648e+06
# 46-50      Food                2.726781e+06
# 51-55      Food                2.315333e+06
# 55+        Food                1.364407e+06
# Name: Filled_Amount, dtype: float64

# %%
revenue_by_marital_status = df.groupby("Marital_Status")["Filled_Amount"].sum()
print(revenue_by_marital_status)

order_by_marital_status = df.groupby("Marital_Status")["Orders"].sum()
print(order_by_marital_status)
# Out:
# Marital_Status
# 0    6.213655e+07
# 1    4.415572e+07
# Name: Filled_Amount, dtype: float64
# Marital_Status
# 0    16243
# 1    11738
# Name: Orders, dtype: int64

# %% [markdown]
# Married customers generate higher total revenue: ₹62.14M
# They also place more orders: 16,243
# Unmarried customers generate ₹44.16M from 11,738 orders.
# So in this dataset, married customers are the stronger segment in terms of both sales volume and total revenue.

# %%
avg_revenue_by_marital_status = revenue_by_marital_status/order_by_marital_status
print(avg_revenue_by_marital_status)
# Out:
# Marital_Status
# 0    3825.435627
# 1    3761.775505
# dtype: float64

# %% [markdown]
# ### Married customers have a slightly higher average revenue per order — about ₹63.66 more per order than unmarried customers.

# %%
revenue_marital_status_gender = df.groupby(["Gender","Marital_Status"])["Filled_Amount"].sum()
print(revenue_marital_status_gender)

order_marital_status_gender = df.groupby(["Gender","Marital_Status"])["Orders"].sum()
print(order_marital_status_gender)
# Out:
# Gender  Marital_Status
# F       0                 4.380692e+07
#         1                 3.059530e+07
# M       0                 1.832963e+07
#         1                 1.356042e+07
# Name: Filled_Amount, dtype: float64
# Gender  Marital_Status
# F       0                 11395
#         1                  8159
# M       0                  4848
#         1                  3579
# Name: Orders, dtype: int64

# %% [markdown]
# Female + Married customers are the strongest segment:
#
# Highest revenue → ₹43.81M
# Highest orders → 11,395
#
# And the interesting part is that married customers outperform unmarried customers for both genders.

# %%
avg_revenue_marital_status_gender = revenue_marital_status_gender/order_marital_status_gender
print(avg_revenue_marital_status_gender)
# Out:
# Gender  Marital_Status
# F       0                 3844.398532
#         1                 3749.883229
# M       0                 3780.864194
#         1                 3788.886172
# dtype: float64

# %% [markdown]
# Female + Married customers have the highest average revenue per order at ₹3,844.40.
#
# Interesting point:
#
# Female + Married → highest
# Male + Unmarried → slightly higher than Male + Married
#
# So total revenue and average revenue per order tell slightly different stories.

# %%
revenue_state_marital_status = df.groupby(["State","Marital_Status"])["Filled_Amount"].sum()
print(revenue_state_marital_status)
# Out:
# State             Marital_Status
# Andhra Pradesh    0                 4.732989e+06
#                   1                 3.313612e+06
# Bihar             0                 2.275957e+06
#                   1                 1.738712e+06
# Delhi             0                 6.717924e+06
#                   1                 4.914256e+06
# Gujarat           0                 2.455104e+06
#                   1                 1.501963e+06
# Haryana           0                 2.535332e+06
#                   1                 1.682539e+06
# Himachal Pradesh  0                 2.882380e+06
#                   1                 2.080988e+06
# Jharkhand         0                 1.723460e+06
#                   1                 1.302996e+06
# Karnataka         0                 7.805946e+06
#                   1                 5.727048e+06
# Kerala            0                 2.258047e+06
#                   1                 1.636445e+06
# ...

# %%
order_state_marital_status = df.groupby(["State","Marital_Status"])["Orders"].sum()
print(order_state_marital_status)
# Out:
# State             Marital_Status
# Andhra Pradesh    0                 1187
#                   1                  867
# Bihar             0                  595
#                   1                  463
# Delhi             0                 1590
#                   1                 1154
# Gujarat           0                  669
#                   1                  398
# Haryana           0                  664
#                   1                  442
# Himachal Pradesh  0                  903
#                   1                  665
# Jharkhand         0                  553
#                   1                  400
# Karnataka         0                 1879
#                   1                 1362
# Kerala            0                  635
#                   1                  502
# Madhya Pradesh    0                 1266
#                   1                  993
# Maharashtra       0                 2212
#                   1                 1587
# ...

# %% [markdown]
# Uttar Pradesh + Married → ₹11.22M revenue, 2,775 orders
# Maharashtra + Married → ₹8.53M, 2,212 orders
# Karnataka + Married → ₹7.81M, 1,879 orders
# Uttar Pradesh + Unmarried → ₹8.14M, 2,034 orders
#
# So UP + Married is the highest-revenue State × Marital Status segment.

# %%
revenue_state_Gender_marital = df.groupby(["State","Gender","Marital_Status"])["Filled_Amount"].sum()
print(revenue_state_Gender_marital)

order_state_Gender_marital = df.groupby(["State","Gender","Marital_Status"])["Orders"].sum()
print(order_state_Gender_marital)
# Out:
# State           Gender  Marital_Status
# Andhra Pradesh  F       0                 3.270401e+06
#                         1                 2.250273e+06
#                 M       0                 1.462588e+06
#                         1                 1.063339e+06
# Bihar           F       0                 1.490947e+06
#                                               ...
# Uttar Pradesh   M       1                 2.469651e+06
# Uttarakhand     F       0                 1.004176e+06
#                         1                 5.888420e+05
#                 M       0                 5.878400e+05
#                         1                 3.400860e+05
# Name: Filled_Amount, Length: 64, dtype: float64
# State           Gender  Marital_Status
# Andhra Pradesh  F       0                 792
#                         1                 602
#                 M       0                 395
#                         1                 265
# Bihar           F       0                 394
# ...

# %% [markdown]
# 🧠 Q31 Insight
#
# From the visible output, for example, Andhra Pradesh:
#
# Female + Married → ₹3.27M
# Female + Unmarried → ₹2.25M
# Male + Married → ₹1.46M
# Male + Unmarried → ₹1.06M

# %%
highest_revenue_state_Gender_marital = revenue_state_Gender_marital.sort_values(ascending=False).head(10)
print(highest_revenue_state_Gender_marital)
# Out:
# State           Gender  Marital_Status
# Uttar Pradesh   F       0                 8.006403e+06
# Maharashtra     F       0                 6.253350e+06
# Karnataka       F       0                 5.896439e+06
# Uttar Pradesh   F       1                 5.674610e+06
# Delhi           F       0                 4.887729e+06
# Maharashtra     F       1                 4.307221e+06
# Karnataka       F       1                 4.046981e+06
# Delhi           F       1                 3.405131e+06
# Andhra Pradesh  F       0                 3.270401e+06
# Uttar Pradesh   M       0                 3.214299e+06
# Name: Filled_Amount, dtype: float64

# %% [markdown]
# The strongest combination is:
#
# Uttar Pradesh + Female + Married → ₹8.01M
#
# And interestingly, your top 10 contains many female segments, especially from UP, Maharashtra, Karnataka, and Delhi.
#
# That's a useful business insight: female customers are the dominant revenue contributors across the highest-performing state segments.

# %%
order_state_Gender_marital = df.groupby(["State","Gender","Marital_Status"])["Orders"].sum()
print(order_state_Gender_marital.sort_values(ascending=False).head(10))
# Out:
# State           Gender  Marital_Status
# Uttar Pradesh   F       0                 1992
# Maharashtra     F       0                 1644
# Uttar Pradesh   F       1                 1410
# Karnataka       F       0                 1363
# Maharashtra     F       1                 1166
# Delhi           F       0                 1112
# Karnataka       F       1                  903
# Madhya Pradesh  F       0                  869
# Andhra Pradesh  F       0                  792
# Uttar Pradesh   M       0                  783
# Name: Orders, dtype: int64

# %%
avg_revenue_state_Gender_marital = revenue_state_Gender_marital/order_state_Gender_marital
print(avg_revenue_state_Gender_marital.sort_values(ascending=False))
# Out:
# State             Gender  Marital_Status
# Karnataka         F       1                 4481.706103
# Delhi             F       1                 4480.435818
# Punjab            M       1                 4468.430769
# Delhi             F       0                 4395.439803
# Karnataka         F       0                 4326.074101
#                                                ...
# Himachal Pradesh  F       1                 2860.316348
# Uttarakhand       F       0                 2836.655367
#                           1                 2790.720379
# Punjab            F       1                 2611.206667
#                   M       0                 2591.681818
# Length: 64, dtype: float64

# %%
revenue_marital_state_gender = df.groupby(["State", "Gender","Marital_Status"])["Filled_Amount"].sum()
percentage_avg_revenue_state_Gender_marital = (revenue_marital_state_gender/gender_revenue)*100
print(percentage_avg_revenue_state_Gender_marital)
# Out:
# State           Gender  Marital_Status
# Andhra Pradesh  F       0                 4.401161
#                         1                 3.028318
#                 M       0                 4.589066
#                         1                 3.336369
# Bihar           F       0                 2.006451
#                                             ...
# Uttar Pradesh   M       1                 7.748862
# Uttarakhand     F       0                 1.351376
#                         1                 0.792438
#                 M       0                 1.844427
#                         1                 1.067065
# Length: 64, dtype: float64

# %%
total_revenue = df["Filled_Amount"].sum()
states_revenue_percentage = (states_revenue/total_revenue) *100
print(states_revenue_percentage.sort_values(ascending=False))
# Out:
# State
# Uttar Pradesh       18.218598
# Maharashtra         13.560648
# Karnataka           12.731870
# Delhi               10.943580
# Madhya Pradesh       7.639360
# Andhra Pradesh       7.570259
# Himachal Pradesh     4.669547
# Haryana              3.968182
# Bihar                3.777009
# Gujarat              3.722816
# Kerala               3.663947
# Jharkhand            2.847296
# Uttarakhand          2.371710
# Rajasthan            1.796376
# Punjab               1.435476
# Telangana            1.083324
# Name: Filled_Amount, dtype: float64

# %% [markdown]
# Your ranking is exactly what we expected:
#
# Uttar Pradesh — 18.22%
# Maharashtra — 13.56%
# Karnataka — 12.73%
# Delhi — 10.94%
# Madhya Pradesh — 7.64%
#
# So the Top 5 states contribute ≈ 63.09% of the overall revenue. 🔥

# %%
# Average revenue per order for each state
avg_revenue_state = states_revenue / states_orders

# Combine all three Series
combined = pd.concat(
    [states_revenue, states_orders, avg_revenue_state],
    axis=1
)

# Rename columns
combined.columns = [
    "Total Revenue",
    "Total Orders",
    "Avg Revenue per Order"
]

# Sort by total revenue and get top 10
combined = combined.sort_values(
    "Total Revenue",
    ascending=False
).head(10)

print(combined)
# Out:
#                   Total Revenue  Total Orders  Avg Revenue per Order
# State
# Uttar Pradesh      1.936496e+07          4809            4026.816848
# Maharashtra        1.441392e+07          3799            3794.135460
# Karnataka          1.353299e+07          3241            4175.561126
# Delhi              1.163218e+07          2744            4239.132756
# Madhya Pradesh     8.120049e+06          2259            3594.532635
# Andhra Pradesh     8.046601e+06          2054            3917.527070
# Himachal Pradesh   4.963368e+06          1568            3165.413265
# Haryana            4.217871e+06          1106            3813.626582
# Bihar              4.014669e+06          1058            3794.583176
# Gujarat            3.957066e+06          1067            3708.590648

# %% [markdown]
# 📊 Your main findings
#
# Uttar Pradesh leads in total revenue — ~₹19.36M.
# Uttar Pradesh also has the highest order volume — 4,809.
# Delhi has the highest average revenue per order among these top 10 — ~₹4,239.
# Karnataka is also strong in order value — ~₹4,176/order.
# Himachal Pradesh has much lower average revenue/order — ~₹3,165 — despite being in the top 10 by revenue.

# %%
revenue_marital_status_gender = df.groupby(["Gender","Marital_Status"])["Filled_Amount"].sum()
gender_revenue = df.groupby("Gender")["Filled_Amount"].sum()
percentage_avg_revenue_Gender_marital= (revenue_marital_status_gender/gender_revenue) * 100
print(percentage_avg_revenue_Gender_marital)
# Out:
# Gender  Marital_Status
# F       0                 58.878515
#         1                 41.121485
# M       0                 57.477576
#         1                 42.522424
# Name: Filled_Amount, dtype: float64

# %% [markdown]
# 🧠 Business Insight
#
# Married customers contribute the larger share of revenue for both genders.
#
# Among females, married customers contribute 58.88% of female revenue.
# Among males, married customers contribute 57.48% of male revenue.
# Unmarried customers contribute roughly 41–43%.
#
# So there isn't a huge difference between the genders in terms of the married/unmarried revenue split.

# %% [markdown]
# ## Customer-Level Analysis
# ### Which customers have generated the highest total revenue?

# %%
highest_revenue_customer = df.groupby("Cust_name")["Filled_Amount"].sum()
top_revenue_customer = highest_revenue_customer.sort_values(ascending=False).head(10)
top_customer_orders = df.groupby("Cust_name")["Orders"].sum()

top_customer_orders = top_customer_orders.loc[top_revenue_customer.index]

print(top_customer_orders)
# Out:
# Cust_name
# Vishakha     106
# Sudevi        71
# Vasudev       58
# Neola         58
# Alejandro     73
# Aastha        62
# Shreyshi      75
# Hazel         57
# Akshat        69
# Gopal         52
# Name: Orders, dtype: int64

# %%
zone_revenue = df.groupby("Zone")["Filled_Amount"].sum()
print(zone_revenue)
state_zone_revenue = df.groupby(["Zone", "State"])["Filled_Amount"].sum()
print(state_zone_revenue)
# Out:
# Zone
# Central     4.163814e+07
# Eastern     7.041125e+06
# Northern    1.261645e+07
# Southern    2.662558e+07
# Western     1.837099e+07
# Name: Filled_Amount, dtype: float64
# Zone      State
# Central   Delhi               1.163218e+07
#           Madhya Pradesh      8.120049e+06
#           Uttar Pradesh       1.936496e+07
#           Uttarakhand         2.520944e+06
# Eastern   Bihar               4.014669e+06
#           Jharkhand           3.026456e+06
# Northern  Haryana             4.217871e+06
#           Himachal Pradesh    4.963368e+06
#           Punjab              1.525800e+06
#           Rajasthan           1.909409e+06
# Southern  Andhra Pradesh      8.046601e+06
#           Karnataka           1.353299e+07
#           Kerala              3.894492e+06
#           Telangana           1.151490e+06
# Western   Gujarat             3.957066e+06
#           Maharashtra         1.441392e+07
# Name: Filled_Amount, dtype: float64

# %%
gender_zone_revenue = df.groupby(["Gender","Zone"])["Filled_Amount"].sum()
print(gender_zone_revenue)

Gender_contribution_within_Zone = (gender_zone_revenue/zone_revenue) *100
print(Gender_contribution_within_Zone)
# Out:
# Gender  Zone
# F       Central     2.887739e+07
#         Eastern     4.765468e+06
#         Northern    8.553002e+06
#         Southern    1.881200e+07
#         Western     1.339436e+07
# M       Central     1.276075e+07
#         Eastern     2.275657e+06
#         Northern    4.063446e+06
#         Southern    7.813581e+06
#         Western     4.976624e+06
# Name: Filled_Amount, dtype: float64
# Gender  Zone
# F       Central     69.353225
#         Eastern     67.680491
#         Northern    67.792472
#         Southern    70.653852
#         Western     72.910418
# M       Central     30.646775
#         Eastern     32.319509
#         Northern    32.207528
#         Southern    29.346148
#         Western     27.089582
# Name: Filled_Amount, dtype: float64

# %%
age_group_zone_revenue = df.groupby(["Age Group","Zone"])["Filled_Amount"].sum()
print(age_group_zone_revenue)

age_group_gender_zone_revenue = df.groupby(["Age Group","Gender","Zone"])["Filled_Amount"].sum()
print(age_group_gender_zone_revenue)
# Out:
# Age Group  Zone
# 0-17       Central     9.459070e+05
#            Eastern     2.583970e+05
#            Northern    3.265590e+05
#            Southern    5.653700e+05
#            Western     6.034200e+05
# 18-25      Central     6.542987e+06
#            Eastern     1.142815e+06
#            Northern    2.221705e+06
#            Southern    4.199608e+06
#            Western     3.128415e+06
# 26-35      Central     1.638298e+07
#            Eastern     2.817856e+06
#            Northern    5.082989e+06
#            Southern    1.075398e+07
#            Western     7.562871e+06
# 36-45      Central     9.041177e+06
#            Eastern     1.422095e+06
#            Northern    2.502217e+06
#            Southern    5.841692e+06
#            Western     3.356316e+06
# 46-50      Central     3.868140e+06
#            Eastern     6.649050e+05
#            Northern    9.365080e+05
#            Southern    2.361293e+06
#            Western     1.414812e+06
# ...

# %% [markdown]
# ## What is the gender distribution of customers in the dataset?

# %%
gender_count = df["Gender"].value_counts()

plt.figure(figsize=(6, 4))
sns.barplot(x=gender_count.index, y=gender_count.values, palette="Set1")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/2769159684.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_count.index, y=gender_count.values, palette="Set1")

# %% [markdown]
# ## Age Group Distribution

# %%
age_group_count = df["Age Group"].value_counts().sort_index()

plt.figure(figsize=(6, 4))
sns.barplot(x=age_group_count.index, y=age_group_count.values,palette="Set2")

plt.title("Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/917924775.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_count.index, y=age_group_count.values,palette="Set2")

# %% [markdown]
# ## Visualize the total revenue generated by each Gender.

# %%
# gender_revenue
plt.Figure(figsize=(8,6))
sns.barplot(x=gender_revenue.index,y=gender_revenue.values,palette="Set2")
plt.title("Gender Revenue Distributation")
plt.xlabel("Gender")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/597494244.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_revenue.index,y=gender_revenue.values,palette="Set2")

# %% [markdown]
# ## Visualize the total revenue generated by each Age Group.

# %%
total_revenue_by_agegroup = df.groupby("Age Group")["Filled_Amount"].sum()
plt.figure(figsize=(6,5))
sns.barplot(x=total_revenue_by_agegroup.index, y=total_revenue_by_agegroup.values,palette="viridis")
plt.title("Total Revenue Generated By Age Group")
plt.xlabel("Age Group")
plt.ylabel("Total Revenue")

plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/1861592444.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_revenue_by_agegroup.index, y=total_revenue_by_agegroup.values,palette="viridis")

# %% [markdown]
# ## Visualize the total revenue generated by each Product Category.

# %%
# product_revenue
plt.figure(figsize=(28,6))
sns.barplot(x=product_revenue.index, y=product_revenue.values,palette="coolwarm")
plt.title("Total Revenue Generate By Each Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/3080055973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_revenue.index, y=product_revenue.values,palette="coolwarm")

# %% [markdown]
# ## Visualize the number of orders for each Product Category.

# %%
#total_orders_category
plt.figure(figsize=(28,6))
sns.barplot(x=total_orders_category.index, y=total_orders_category.values,palette="coolwarm")
plt.title("Total Order Generate By Each Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Order")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/4004291849.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_orders_category.index, y=total_orders_category.values,palette="coolwarm")

# %% [markdown]
# ## Visualize the average revenue generated per order for each Product Category.

# %%
category_revenue = df.groupby("Product_Category")["Filled_Amount"].sum()

product_revenue_avg = category_revenue/total_orders_category
plt.figure(figsize=(28,6))
sns.barplot(x=product_revenue_avg.index, y=product_revenue_avg.values,palette="coolwarm")
plt.title("Average Revenue Generated per Order for Each Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Revenue per Order")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/3632821421.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_revenue_avg.index, y=product_revenue_avg.values,palette="coolwarm")

# %% [markdown]
# ## Visualize the total revenue generated by each State.

# %%
#states_revenue
plt.figure(figsize=(22,6))
sns.barplot(x=states_revenue.index, y=states_revenue.values,palette="coolwarm")
plt.title("Total Revenue Generated by Each State")
plt.xlabel("State")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/508456228.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=states_revenue.index, y=states_revenue.values,palette="coolwarm")

# %% [markdown]
# ## Visualize the total revenue generated by each Zone.

# %%
zone_revenue
plt.figure(figsize=(12,6))
sns.barplot(x=zone_revenue.index, y=zone_revenue.values,palette="pastel")
plt.title("Total Revenue Generated by Each Zone")
plt.xlabel("Zone")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/87687325.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=zone_revenue.index, y=zone_revenue.values,palette="pastel")

# %% [markdown]
# ## Visualize the revenue contribution of Female vs Male customers within each Zone.

# %%
gender_zone_revenue = df.groupby(["Gender", "Zone"])["Filled_Amount"].sum().reset_index()

plt.figure(figsize=(12,6))

sns.barplot(
    data=gender_zone_revenue,
    x="Zone",
    y="Filled_Amount",
    hue="Gender",
    palette=["#4C72B0", "#55A868", "#DD8452"]
)

plt.title("Total Revenue Generated by Gender for Each Zone")
plt.xlabel("Zone")
plt.ylabel("Total Revenue")

plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/338493426.py:5: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ## Occupation Revenue

# %%
plt.figure(figsize=(20,6))
sns.barplot(x=revenue_occupation.index,y=revenue_occupation.values,palette="dark")
plt.title("Total Revenue generated by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/2157294368.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_occupation.index,y=revenue_occupation.values,palette="dark")

# %% [markdown]
# ## Gender × Occupation

# %%
data = revenue_by_Gender_and_Occupation.reset_index()

plt.figure(figsize=(15,6))

sns.barplot(
    data=data,
    x="Occupation",
    y="Filled_Amount",
    hue="Gender",
    palette=["#4C72B0", "#55A868"]
)

plt.title("Total Revenue Generated by Gender for Each Occupation")
plt.xlabel("Occupation")
plt.ylabel("Total Revenue")

plt.show()

# %% [markdown]
# ## Marital Status

# %%
plt.figure(figsize=(8,6))

sns.barplot(x=revenue_by_marital_status.index, y=revenue_by_marital_status.values,palette="muted")
plt.title("Total Revenue Generated by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Total Revenue")

plt.show()
# Out:
# /var/folders/z5/7fqrh9px0vv_sn9k22crjd480000gn/T/ipykernel_13669/346103888.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_by_marital_status.index, y=revenue_by_marital_status.values,palette="muted")

# %% [markdown]
# ## Age Group × Zone

# %%
data = age_group_zone_revenue.reset_index()

plt.figure(figsize=(15,6))
sns.barplot(
    data=data,
    x= "Age Group",
    y="Filled_Amount",
    hue="Zone",
    palette="deep"
)

plt.title("Total Revenue Generated by each Age Group by each Zone")
plt.xlabel("Age Group")
plt.ylabel("Total Revenue")

plt.show()

# %% [markdown]
# ## Final Main Visualization

# %%
data = df.groupby(["Product_Category", "Age Group"])["Filled_Amount"].sum().reset_index()

plt.figure(figsize=(30,10))

sns.barplot(
    data=data,
    x= "Product_Category",
    y="Filled_Amount",
    hue="Age Group",
    palette="mako"
)

plt.title("Total Revenue by Product Category and Age Group")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")

plt.show()
